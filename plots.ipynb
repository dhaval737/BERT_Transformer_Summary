# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

#df = pd.DataFrame({'Model':['Baseline','BERT','BigBird'], 'Recall':[53.031,21.237,24.993],
#                  'Precision':[36.782, 48.731, 42.779],'f1':[41.363,28.053, 28.802]})

x = ['Baseline','BERTSum','BigBird']
y = [53.031, 21.237, 54.991]
z = [36.782, 48.731, 22.575]
w = [41.636, 28.052, 30.672]
#ax=plt.subplot()

df = pd.DataFrame({'Recall': y,
                   'Precision': z,'f1':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-1")
#plt.style.use('grayscale')

plt.show()

# %%
x = ['Baseline','BERTSum','BigBird']
y = [17.167,5.466,15.788]
z = [11.939, 13.106, 6.426]
w = [13.490,7.290, 8.740]
#ax=plt.subplot()

df = pd.DataFrame({'Recall': y,
                   'Precision': z,'f1':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-2")
plt.show()

# %%
x = ['Baseline','BERT','BigBird']
y = [7.043,2.207, 5.875]
z = [4.855, 5.424, 2.398]
w = [5.518, 2.953, 3.256]
#ax=plt.subplot()

df = pd.DataFrame({'Recall': y,
                   'Precision': z,'f1':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-3")
plt.show()

# %%
x = ['Baseline','BERTSum','BigBird']
y = [4.078, 1.371, 3.268]
z = [2.792, 3.435, 1.342]
w = [3.190, 1.840, 1.817]
#ax=plt.subplot()

df = pd.DataFrame({'Recall': y,
                   'Precision': z,'f1':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-4")
plt.show()
