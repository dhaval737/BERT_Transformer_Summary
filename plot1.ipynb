# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

#df = pd.DataFrame({'Model':['Baseline','BERT','BigBird'], 'Recall':[53.031,21.237,24.993],
#                  'Precision':[36.782, 48.731, 42.779],'f1':[41.363,28.053, 28.802]})

x = ['Recall','Precision','f1']
#x = ['Baseline','BERTSum','BigBird']
#y = [53.031, 21.237, 54.991]
#z = [36.782, 48.731, 22.575]
#w = [41.636, 28.052, 30.672]
y = [53.031, 36.782, 41.636]
z = [21.237, 48.731, 28.052]
w = [54.991, 22.575, 30.672]
#ax=plt.subplot()

df = pd.DataFrame({'Baseline': y,
                   'BERTSum': z,'BigBird':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-1")
#plt.style.use('grayscale')

plt.show()

# %%
x = ['Recall','Precision','f1']
#y = [17.167,5.466,15.788]
#z = [11.939, 13.106, 6.426]
#w = [13.490,7.290, 8.740]
y = [17.167,11.939, 13.490]
z = [5.466, 13.106, 7.290]
w = [15.788,6.426, 8.740]
#ax=plt.subplot()

df = pd.DataFrame({'Baseline': y,
                   'BERTSum': z,'BigBird':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-2")
plt.show()

# %%
x = ['Recall','Precision','f1']
#y = [7.043,2.207, 5.875]
#z = [4.855, 5.424, 2.398]
#w = [5.518, 2.953, 3.256]

y = [7.043,4.855,5.518]
z = [2.207, 5.424,2.953]
w = [5.875, 2.398,3.256]


df = pd.DataFrame({'Baseline': y,
                   'BERTSum': z,'BigBird':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-3")
plt.show()

# %%
x = ['Recall','Precision','f1']
#y = [4.078, 1.371, 3.268]
#z = [2.792, 3.435, 1.342]
#w = [3.190, 1.840, 1.817]

y = [4.078,2.792,3.190]
z = [1.371,3.435,1.840]
w = [3.268,1.342,1.817]

df = pd.DataFrame({'Baseline': y,
                   'BERTSum': z,'BigBird':w}, index=x)
df.plot.bar(figsize=(8,4))
plt.title("Rouge-4")
plt.show()
